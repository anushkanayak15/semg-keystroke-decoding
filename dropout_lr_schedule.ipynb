# %%
# Single-user training
# 000
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.0 \
  optimizer.lr=1e-3 \
  lr_scheduler=step \
  lr_scheduler.scheduler.gamma=1.0 \
  hydra.run.dir=logs/dropout_0/lr_1e-3/scheduler_no \
  # --multirun
# Out:
# [2026-03-10 06:08:11,196][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
#001
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.0 \
  optimizer.lr=1e-3 \
  lr_scheduler=linear_warmup_cosine_annealing \
  hydra.run.dir=logs/dropout_0/lr_1e-3/scheduler_cosineannealing \
  # --multirun
# Out:
# [2026-03-10 04:07:02,727][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 002
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.0 \
  optimizer.lr=1e-3 \
  lr_scheduler=reduce_on_plateau \
  lr_scheduler.monitor="val/CER" \
  hydra.run.dir=logs/dropout_0/lr_1e-3/scheduler_reduceonplateau \
  # --multirun
# Out:
# [2026-03-10 04:51:37,990][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 010
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.0 \
  optimizer.lr=5e-4 \
  lr_scheduler=step \
  lr_scheduler.scheduler.gamma=1.0 \
  hydra.run.dir=logs/dropout_0/lr_5e-4/scheduler_no \
  # --multirun
# Out:
# [2026-03-10 06:42:22,472][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 011
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.0 \
  optimizer.lr=5e-4 \
  lr_scheduler=linear_warmup_cosine_annealing \
  hydra.run.dir=logs/dropout_0/lr_5e-4/scheduler_cosineannealing \
  # --multirun
# Out:
# [2026-03-10 07:16:56,089][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 012
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.0 \
  optimizer.lr=5e-4 \
  lr_scheduler=reduce_on_plateau \
  lr_scheduler.monitor="val/CER" \
  hydra.run.dir=logs/dropout_0/lr_5e-4/scheduler_reduceonplateau \
  # --multirun
# Out:
# [2026-03-10 07:51:45,715][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 020
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.0 \
  optimizer.lr=1e-4 \
  lr_scheduler=step \
  lr_scheduler.scheduler.gamma=1.0 \
  hydra.run.dir=logs/dropout_0/lr_1e-4/scheduler_no \
  # --multirun
# Out:
# [2026-03-10 08:25:59,373][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 021
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.0 \
  optimizer.lr=1e-4 \
  lr_scheduler=linear_warmup_cosine_annealing \
  hydra.run.dir=logs/dropout_0/lr_1e-4/scheduler_cosineannealing \
  # --multirun
# Out:
# [2026-03-10 20:08:45,721][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 022
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.0 \
  optimizer.lr=1e-4 \
  lr_scheduler=reduce_on_plateau lr_scheduler.monitor="val/CER" \
  hydra.run.dir=logs/dropout_0/lr_1e-4/scheduler_reduceonplateau \
  # --multirun
# Out:
# [2026-03-10 19:33:36,380][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 100
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.2 \
  optimizer.lr=1e-3 \
  lr_scheduler=step \
  lr_scheduler.scheduler.gamma=1.0 \
  hydra.run.dir=logs/dropout_02/lr_1e-3/scheduler_no \
  # --multirun
# Out:
# [2026-03-10 09:01:35,249][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 101
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.2 \
  optimizer.lr=1e-3 \
  lr_scheduler=linear_warmup_cosine_annealing \
  hydra.run.dir=logs/dropout_02/lr_1e-3/scheduler_cosineannealing \
  # --multirun
# Out:
# [2026-03-10 09:35:57,621][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 102
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.2 \
  optimizer.lr=1e-3 \
  lr_scheduler=reduce_on_plateau lr_scheduler.monitor="val/CER" \
  hydra.run.dir=logs/dropout_02/lr_1e-3/scheduler_reduceonplateau \
  # --multirun
# Out:
# [2026-03-10 10:11:33,432][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 110
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.2 \
  optimizer.lr=5e-4 \
  lr_scheduler=step \
  lr_scheduler.scheduler.gamma=1.0 \
  hydra.run.dir=logs/dropout_02/lr_5e-4/scheduler_no \
  # --multirun
# Out:
# [2026-03-10 10:46:48,305][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 111
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.2 \
  optimizer.lr=5e-4 \
  lr_scheduler=linear_warmup_cosine_annealing \
  hydra.run.dir=logs/dropout_02/lr_5e-4/scheduler_cosineannealing \
  # --multirun
# Out:
# [2026-03-10 11:21:55,967][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 112
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.2 \
  optimizer.lr=5e-4 \
  lr_scheduler=reduce_on_plateau lr_scheduler.monitor="val/CER" \
  hydra.run.dir=logs/dropout_02/lr_5e-4/scheduler_reduceonplateau \
  # --multirun
# Out:
# [2026-03-10 11:56:23,650][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 120
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.2 \
  optimizer.lr=1e-4 \
  lr_scheduler=step \
  lr_scheduler.scheduler.gamma=1.0 \
  hydra.run.dir=logs/dropout_02/lr_1e-4/scheduler_no \
  # --multirun
# Out:
# [2026-03-10 12:31:38,164][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 121
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.2 \
  optimizer.lr=1e-4 \
  lr_scheduler=linear_warmup_cosine_annealing \
  hydra.run.dir=logs/dropout_02/lr_1e-4/scheduler_cosineannealing \
  # --multirun
# Out:
# [2026-03-10 13:06:45,021][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 122
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.2 \
  optimizer.lr=1e-4 \
  lr_scheduler=reduce_on_plateau lr_scheduler.monitor="val/CER" \
  hydra.run.dir=logs/dropout_02/lr_1e-4/scheduler_reduceonplateau \
  # --multirun
# Out:
# [2026-03-10 13:40:59,551][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 200
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.4 \
  optimizer.lr=1e-3 \
  lr_scheduler=step \
  lr_scheduler.scheduler.gamma=1.0 \
  hydra.run.dir=logs/dropout_04/lr_1e-3/scheduler_no \
  # --multirun
# Out:
# [2026-03-10 14:16:01,677][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 201
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.4 \
  optimizer.lr=1e-3 \
  lr_scheduler=linear_warmup_cosine_annealing \
  hydra.run.dir=logs/dropout_04/lr_1e-3/scheduler_cosineannealing \
  # --multirun
# Out:
# [2026-03-10 14:51:01,707][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 202
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.4 \
  optimizer.lr=1e-3 \
  lr_scheduler=reduce_on_plateau lr_scheduler.monitor="val/CER" \
  hydra.run.dir=logs/dropout_04/lr_1e-3/scheduler_reduceonplateau \
  # --multirun
# Out:
# [2026-03-10 15:26:18,184][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 210
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.4 \
  optimizer.lr=5e-4 \
  lr_scheduler=step \
  lr_scheduler.scheduler.gamma=1.0 \
  hydra.run.dir=logs/dropout_04/lr_5e-4/scheduler_no \
  # --multirun
# Out:
# [2026-03-10 16:00:30,579][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 211
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.4 \
  optimizer.lr=5e-4 \
  lr_scheduler=linear_warmup_cosine_annealing \
  hydra.run.dir=logs/dropout_04/lr_5e-4/scheduler_cosineannealing \
  # --multirun
# Out:
# [2026-03-10 16:36:18,075][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 212
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.4 \
  optimizer.lr=5e-4 \
  lr_scheduler=reduce_on_plateau lr_scheduler.monitor="val/CER" \
  hydra.run.dir=logs/dropout_04/lr_5e-4/scheduler_reduceonplateau \
  # --multirun
# Out:
# [2026-03-10 17:10:47,314][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 220
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.4 \
  optimizer.lr=1e-4 \
  lr_scheduler=step \
  lr_scheduler.scheduler.gamma=1.0 \
  hydra.run.dir=logs/dropout_04/lr_1e-4/scheduler_no \
  # --multirun
# Out:
# [2026-03-10 17:46:43,967][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 221
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.4 \
  optimizer.lr=1e-4 \
  lr_scheduler=linear_warmup_cosine_annealing \
  hydra.run.dir=logs/dropout_04/lr_1e-4/scheduler_cosineannealing \
  # --multirun
# Out:
# [2026-03-10 18:22:48,172][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# Single-user training
# 222
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
  model="cnn_bilstm_ctc" \
  dataset.root=/home/neiljohnson/project/EMG_Project_Data/89335547 \
  user="single_user" \
  trainer.max_epochs=50 \
  trainer.accelerator=gpu trainer.devices=1 \
  module.dropout=0.4 \
  optimizer.lr=1e-4 \
  lr_scheduler=reduce_on_plateau lr_scheduler.monitor="val/CER" \
  hydra.run.dir=logs/dropout_04/lr_1e-4/scheduler_reduceonplateau \
  # --multirun
# Out:
# [2026-03-10 18:58:33,957][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs/
