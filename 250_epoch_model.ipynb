# %%
# !LD_LIBRARY_PATH="" python -m emg2qwerty.train \
    model=cnn_bilstm_ctc \
    transforms=cnn_bilstm_preproc_aug \
    user=single_user \
    trainer.max_epochs=250 \
    trainer.accelerator=gpu \
    trainer.devices=1 \
    module.cnn_layers_count=3 \
    module.cnn_kernel_size=9 \
    module.lstm_hidden=512 \
    module.lstm_layers=3 \
    module.dropout=0.4 \
    optimizer.lr=1e-3 \
    lr_scheduler=cosine_annealing \
    normalize.mode=per_channel_zscore \
    gaussian_noise.std=0.01 \
    amplitude_scale.scale=0.0 \
    channel_dropout.drop_prob=0.1 \
    hydra.run.dir=logs/final
